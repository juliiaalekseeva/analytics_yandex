# %% [markdown]
# # Дашборд

# %% [markdown]
# Набор номер 2

# %% [markdown]
# https://public.tableau.com/authoring/_16801684931850/Dashboard1#1

# %% [markdown]
# ![image.png](attachment:image.png)
